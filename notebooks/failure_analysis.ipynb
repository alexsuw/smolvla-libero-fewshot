# %% [markdown]
# # Failure analysis
#
# Loads final per-rollout records, videos and traces generated by the evaluation CLI. No result is inferred from a filename.

# %%
from pathlib import Path
from IPython.display import Markdown, Video, display

rollouts = list(Path("artifacts").glob("**/rollouts.jsonl"))
if not rollouts:
    display(Markdown("Evaluation artifacts are not available yet."))
else:
    display(Markdown(f"Found {len(rollouts)} rollout record file(s)."))
