# %% [markdown]
# # Training curves
#
# Live monitoring uses TensorBoard logs from `VLA_RUNS_DIR`. The notebook does not own the training process.

# %%
import os
from IPython.display import Markdown, display

runs_dir = os.environ.get("VLA_RUNS_DIR")
display(Markdown(f"TensorBoard log root: `{runs_dir or 'VLA_RUNS_DIR is not set'}`"))
# In Colab/Jupyter after M5: %load_ext tensorboard; %tensorboard --logdir $VLA_RUNS_DIR
